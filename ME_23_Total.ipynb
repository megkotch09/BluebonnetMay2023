# %%
# !pip install geopandas
# !pip install matplotlib
# !pip install folium
# !pip install requests

import pandas as pd
import geopandas as gpd
import folium
import requests
import os
import numbers
import math

from google.colab import drive
drive.mount('/content/drive')

# %%
# Set your Census Bureau API key
api_key = "8a0b76a97aa387f1d801ca752ec8983574f5c307"

# Set the base URL for the API
base_url = "https://api.census.gov/data"

# Set the variables you want to retrieve
variables = ["B01001_001E"]  # Example variables (total population, white population, Hispanic population)

# Set the geographic parameters for Maine
state_fips = "23"  # Maine FIPS code

# Construct the API request URL with parameters
api_url = base_url + "/2021/acs/acs5?get=" + ",".join(variables) + "&for=county%20subdivision:*&in=state:" + state_fips + "&key=" + api_key

# Send the request and get the response
response = requests.get(api_url)

# Parse the response data (assuming it's in JSON format)
data = response.json()

# %%
# Extract the variable names from the first row of the response
headers = ["Total", "State", "County", "County Sub"]
#headers = data[0]

# Extract the data values from the second row of the response
rows = data[1:]

# Map the variable names to their corresponding values
df = pd.DataFrame(rows, columns=headers)

#display(df) # yas slay queen

df['ALL'] = df['State'] + df['County'] + df['County Sub']
#display(df)
#print(df)

# %%
# Load shapefile data (left sidebar!!)
shapefile_path = "/content/drive/MyDrive/GT/bluebonnet!!/mine - april 2023/Maine/cb_2022_23_cousub_500k/cb_2022_23_cousub_500k.shp"

shapefile = gpd.read_file(shapefile_path)

shapefile.drop(shapefile.columns[[4, 7, 8]], axis=1, inplace=True)

#print(shapefile)

json = shapefile.to_json()

df2 = pd.DataFrame(shapefile)

df = df.astype(int)
shapefile['GEOID'] = shapefile['GEOID'].astype(int)

#print(df)

# %%
merged_data = shapefile.merge(df, left_on="GEOID", right_on="ALL", how="left")
#print(merged_data)

#df['ALL'] corresponds to shapefile['GEOID']

# %%
# Create a base map centered at Maine
map_center = [45.2538, -69.4455]  # Latitude and longitude of Maine
m = folium.Map(location=map_center, zoom_start=7)
bins = generate_bins(15)

# %%
# Overlay the demographic data as a choropleth map
folium.Choropleth(
    geo_data=json, #this is supposed to be a json file
    name="choropleth",
    data=df, #this is supposed to be a dataframe
    #columns=["ALL", "Total", "White", "Hispanic", "Asian Indian", "Bangladeshi"],
    columns=["ALL", "Total"],
    key_on="feature.properties.GEOID",
    fill_color="Spectral",
    fill_opacity=0.9,
    line_opacity=0.2,
    legend_name="Population",
    bins=bins
).add_to(m)

folium.LayerControl().add_to(m)

# Display the map
#m.save("new_hampshire_demographics_map.html")

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_37fd5be159911dd38bb38537019e01cb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_37fd5be159911dd38bb38537019e01cb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_37fd5be159911dd38bb38537019e01cb = L.map(
#                 &quot;map_37fd5be159911dd38bb38537019e01cb&quot;,
#                 {
#                     center: [45.2538, -69.4455],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2c9d9757e0fdafcd1586d0b1af264d34 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_37fd5be159911dd38bb38537019e01cb);
#
#
#             var choropleth_a4445451acdfa601fd18884c06476467 = L.featureGroup(
#                 {}
#             ).addTo(map_37fd5be159911dd38bb38537019e01cb);
#
#
#         function geo_json_571a0d3e111f1ae7f0ec6d4dd93ef53b_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;5&quot;: case &quot;7&quot;: case &quot;31&quot;: case &quot;32&quot;: case &quot;41&quot;: case &quot;57&quot;: case &quot;71&quot;: case &quot;77&quot;: case &quot;89&quot;: case &quot;95&quot;: case &quot;97&quot;: case &quot;98&quot;: case &quot;128&quot;: case &quot;139&quot;: case &quot;145&quot;: case &quot;151&quot;: case &quot;154&quot;: case &quot;173&quot;: case &quot;179&quot;: case &quot;202&quot;: case &quot;204&quot;: case &quot;214&quot;: case &quot;215&quot;: case &quot;249&quot;: case &quot;260&quot;: case &quot;306&quot;: case &quot;313&quot;: case &quot;343&quot;: case &quot;362&quot;: case &quot;417&quot;: case &quot;419&quot;: case &quot;443&quot;: case &quot;457&quot;: case &quot;481&quot;: case &quot;497&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#e25249&quot;, &quot;fillOpacity&quot;: 0.9, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;1&quot;: case &quot;22&quot;: case &quot;38&quot;: case &quot;92&quot;: case &quot;156&quot;: case &quot;201&quot;: case &quot;224&quot;: case &quot;227&quot;: case &quot;241&quot;: case &quot;262&quot;: case &quot;263&quot;: case &quot;267&quot;: case &quot;294&quot;: case &quot;295&quot;: case &quot;301&quot;: case &quot;319&quot;: case &quot;324&quot;: case &quot;330&quot;: case &quot;333&quot;: case &quot;336&quot;: case &quot;369&quot;: case &quot;394&quot;: case &quot;404&quot;: case &quot;424&quot;: case &quot;428&quot;: case &quot;430&quot;: case &quot;445&quot;: case &quot;450&quot;: case &quot;462&quot;: case &quot;466&quot;: case &quot;468&quot;: case &quot;480&quot;: case &quot;495&quot;: case &quot;518&quot;: case &quot;529&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#3e77b5&quot;, &quot;fillOpacity&quot;: 0.9, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;2&quot;: case &quot;53&quot;: case &quot;81&quot;: case &quot;135&quot;: case &quot;225&quot;: case &quot;226&quot;: case &quot;250&quot;: case &quot;289&quot;: case &quot;291&quot;: case &quot;292&quot;: case &quot;296&quot;: case &quot;321&quot;: case &quot;331&quot;: case &quot;332&quot;: case &quot;335&quot;: case &quot;340&quot;: case &quot;388&quot;: case &quot;392&quot;: case &quot;396&quot;: case &quot;407&quot;: case &quot;415&quot;: case &quot;422&quot;: case &quot;426&quot;: case &quot;429&quot;: case &quot;456&quot;: case &quot;458&quot;: case &quot;461&quot;: case &quot;463&quot;: case &quot;464&quot;: case &quot;475&quot;: case &quot;476&quot;: case &quot;479&quot;: case &quot;500&quot;: case &quot;506&quot;: case &quot;512&quot;: case &quot;513&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#5e4fa2&quot;, &quot;fillOpacity&quot;: 0.9, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;3&quot;: case &quot;4&quot;: case &quot;6&quot;: case &quot;11&quot;: case &quot;23&quot;: case &quot;35&quot;: case &quot;50&quot;: case &quot;55&quot;: case &quot;56&quot;: case &quot;80&quot;: case &quot;84&quot;: case &quot;122&quot;: case &quot;134&quot;: case &quot;148&quot;: case &quot;160&quot;: case &quot;172&quot;: case &quot;191&quot;: case &quot;194&quot;: case &quot;196&quot;: case &quot;217&quot;: case &quot;223&quot;: case &quot;230&quot;: case &quot;246&quot;: case &quot;261&quot;: case &quot;286&quot;: case &quot;323&quot;: case &quot;371&quot;: case &quot;375&quot;: case &quot;377&quot;: case &quot;399&quot;: case &quot;425&quot;: case &quot;434&quot;: case &quot;449&quot;: case &quot;452&quot;:

# %%
def generate_bins(nbins):
  quantiles = []
  for i in range(0, nbins+1):
    quantiles.append(i/nbins)

  bins = list(df['Total'].quantile(quantiles))

  return bins
